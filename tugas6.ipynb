# %%
# !pip install experta
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for frozendict: filename=frozendict-1.2-py3-none-any.whl size=3149 sha256=13a71b5f71bdd4139af09dacdb49b01387820f8241dfe859d48c4b1688ec1d55
#   Stored in directory: /root/.cache/pip/wheels/49/ac/f8/cb8120244e710bdb479c86198b03c7b08c3c2d3d2bf448fd6e
# Successfully built frozendict
# ...
#   Attempting uninstall: frozendict
#     Found existing installation: frozendict 2.4.6
#     Uninstalling frozendict-2.4.6:
#       Successfully uninstalled frozendict-2.4.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yfinance 0.2.55 requires frozendict>=2.3.4, but you have frozendict 1.2 which is incompatible.
# ...

# %%
# !pip install --upgrade frozendict
# Out:
# ...
#   Attempting uninstall: frozendict
#     Found existing installation: frozendict 1.2
#     Uninstalling frozendict-1.2:
#       Successfully uninstalled frozendict-1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# experta 1.9.4 requires frozendict==1.2, but you have frozendict 2.4.6 which is incompatible.
# ...

# %%
from experta import *

class Diagnosis(KnowledgeEngine):
    @Rule(Fact(cough=True) & Fact(fever=True) & Fact(fatigue=True))
    def flu(self):
        print("Diagnosis: you may have the flu.")

    @Rule(Fact(cough=True) & Fact(fever=True) & Fact(breathing_difficulty=True))
    def pneumonia(self):
        print("Diagnosis: you may have pneumonia.")

    @Rule(Fact(sneezing=True) & Fact(runny_nose=True) & Fact(cough=False))
    def cold(self):
        print("Diagnosis: you may have a common cold.")

    @Rule(Fact(sore_throat=True) & Fact(fever=True))
    def throat_infection(self):
        print("Diagnosis: you may have a throat infection.")

    @Rule(Fact(cough=False) & Fact(fever=False) & Fact(fatigue=False))
    def healthy(self):
        print("Diagnosis: you seem to be healthy.")

    # New diseases
    @Rule(Fact(cough=True) & Fact(fever=True) & Fact(sore_throat=True) & Fact(fatigue=True))
    def strep_throat(self):
        print("Diagnosis: you may have strep throat.")

    @Rule(Fact(fever=True) & Fact(fatigue=True) & Fact(breathing_difficulty=True) & Fact(chest_pain=True))
    def covid(self):
        print("Diagnosis: you may have COVID-19.")

    @Rule(Fact(runny_nose=True) & Fact(sneezing=True) & Fact(itchy_eyes=True))
    def allergic_rhinitis(self):
        print("Diagnosis: you may have allergic rhinitis (hay fever).")

    @Rule(Fact(cough=True) & Fact(fever=True) & Fact(chest_pain=True) & Fact(breathing_difficulty=True))
    def bronchitis(self):
        print("Diagnosis: you may have bronchitis.")

def get_input():
    """Helper function to get user input as boolean (yes/no)."""
    def ask_question(question):
        return input(question + " (yes/no) ").strip().lower() == "yes"

    return {
        "cough": ask_question("Do you have a cough?"),
        "fever": ask_question("Do you have a fever?"),
        "fatigue": ask_question("Do you feel tired?"),
        "sore_throat": ask_question("Do you have a sore throat?"),
        "runny_nose": ask_question("Do you have a runny nose?"),
        "sneezing": ask_question("Do you have sneezing?"),
        "breathing_difficulty": ask_question("Do you have difficulty breathing?"),
        "chest_pain": ask_question("Do you have chest pain?"),
        "itchy_eyes": ask_question("Do you have itchy eyes?"),
    }

# Running the expert system
if __name__ == "__main__":
    symptoms = get_input()
    engine = Diagnosis()
    engine.reset()  # Reset the knowledge system

    for symptom, present in symptoms.items():
        engine.declare(Fact({symptom: present}))  # Declare facts

    engine.run()  # Run the expert system
# Out:
# Do you have a cough? (yes/no) yes
# Do you have a fever? (yes/no) yes
# Do you feel tired? (yes/no) yes
# Do you have a sore throat? (yes/no) yes
# Do you have a runny nose? (yes/no) yes
# Do you have sneezing? (yes/no) yes
# Do you have difficulty breathing? (yes/no) yes
# Do you have chest pain? (yes/no) no
# Do you have itchy eyes? (yes/no) no
